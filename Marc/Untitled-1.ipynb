# %%
import pandas as pd
import requests
import json

# %%
start_date="2021-06-29"
end_date="2018-06-28"

# %%
nat_gas="https://data.nasdaq.com/api/v3/datasets/CHRIS/CME_NG1"

# %%
nat_gas_call = requests.get(nat_gas).json()

# Display the response data
print(json.dumps(nat_gas_call, indent=4, sort_keys=True))
# Out:
# {
#     "dataset": {
#         "collapse": null,
#         "column_index": null,
#         "column_names": [
#             "Date",
#             "Open",
#             "High",
#             "Low",
#             "Last",
#             "Change",
#             "Settle",
#             "Volume",
#             "Previous Day Open Interest"
#         ],
#         "data": [
#             [
#                 "2021-06-29",
#                 3.583,
#                 3.811,
#                 3.571,
#                 3.658,
#                 0.037,
#                 3.63,
#                 201343.0,
#                 222230.0
#             ],
#             [
#                 "2021-06-28",
#                 3.502,
#                 3.631,
#                 3.485,
#                 3.595,
#                 0.121,
#                 3.617,
#                 6622.0,
#                 3907.0
#             ],
#             [
#                 "2021-06-25",
#                 3.425,
# ...

# %%
natgas_df= {
"price_usd":[
 nat_gas_call["dataset"]["data"][0][4]]}

natgas_df=pd.DataFrame(natgas_df,index=["gas"])

natgas_df
# Out:
#      price_usd
# gas      3.658
