# %%
import pandas as pd
import hvplot.pandas
import os
import requests
import json
import alpaca_trade_api as tradeapi

from pathlib import Path

# %matplotlib inline

# Warning filtration
import warnings
warnings.filterwarnings("ignore")

from dotenv import load_dotenv
load_dotenv('api.env')
# Out:
# True

# %%
# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

# Verify that Alpaca key and secret were correctly loaded
print(f"Alpaca Key type: {type(alpaca_api_key)}")
print(f"Alpaca Secret Key type: {type(alpaca_secret_key)}")

# Create the Alpaca API object
alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")
# Out:
# Alpaca Key type: <class 'str'>
# Alpaca Secret Key type: <class 'str'>

# %%
# Format current date as ISO format
today = pd.Timestamp("2023-01-01", tz="America/New_York").isoformat()
five_yr_ago = pd.Timestamp("2018-01-01", tz="America/New_York").isoformat()
# Set the tickers
tickers = ["WTI"]
# Set timeframe to one day ('1Day') for the Alpaca API
timeframe = "1Day"
# Get current closing prices for FB and TWTR
df_portfolio = alpaca.get_bars(
    tickers,
    timeframe,
    start = five_yr_ago,
    end = today
).df

# Display sample data
df_portfolio
# Out:
#                            open    high     low  close   volume  trade_count  \
# timestamp
# 2018-01-02 05:00:00+00:00  3.35  3.7450  3.3490   3.72  5115480        11936
# 2018-01-03 05:00:00+00:00  3.83  4.3000  3.8205   4.16  5485831        15916
# 2018-01-04 05:00:00+00:00  4.18  4.2900  3.9107   4.24  3950475        11869
# 2018-01-05 05:00:00+00:00  4.08  4.3900  4.0300   4.36  3298406        10547
# 2018-01-08 05:00:00+00:00  4.40  4.4700  4.2400   4.46  2576900        10466
# ...                         ...     ...     ...    ...      ...          ...
# 2022-12-23 05:00:00+00:00  5.54  5.7900  5.5400   5.73  2283128        11693
# 2022-12-27 05:00:00+00:00  5.78  5.8141  5.6884   5.79  2645351        12802
# 2022-12-28 05:00:00+00:00  5.75  5.7600  5.4100   5.46  2983536        14029
# 2022-12-29 05:00:00+00:00  5.41  5.6350  5.3300   5.59  2211176        12928
# 2022-12-30 05:00:00+00:00  5.51  5.6200  5.4900   5.58  4032384        10936
#
#                                vwap symbol
# timestamp
# 2018-01-02 05:00:00+00:00  3.628248    WTI
# 2018-01-03 05:00:00+00:00  4.145994    WTI
# 2018-01-04 05:00:00+00:00  4.126449    WTI
# 2018-01-05 05:00:00+00:00  4.242889    WTI
# 2018-01-08 05:00:00+00:00  4.365510    WTI
# ...                             ...    ...
# 2022-12-23 05:00:00+00:00  5.702898    WTI
# 2022-12-27 05:00:00+00:00  5.762243    WTI
# 2022-12-28 05:00:00+00:00  5.494421    WTI
# 2022-12-29 05:00:00+00:00  5.566587    WTI
# 2022-12-30 05:00:00+00:00  5.564230    WTI
#
# [1259 rows x 8 columns]
